# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

base_tpi = pickle.load(open("/Users/jason.debacker/repos/wealthtax/Python/OUTPUT_BASELINE/sigma2.0/TPI/TPI_vars.pkl", "rb"), encoding='latin1')
wealth_tpi = pickle.load(open("/Users/jason.debacker/repos/wealthtax/Python/OUTPUT_WEALTH_REFORM/sigma2.0/TPI/TPI_vars.pkl", "rb"), encoding='latin1')

# %%
plt.plot(base_tpi['K'])

# %%
plt.plot(base_tpi['Y'])

# %%
plt.plot(base_tpi['L'])

# %%
plt.plot(wealth_tpi['K'])

# %%
plt.plot(wealth_tpi['Y'])

# %%
plt.plot(wealth_tpi['L'])
